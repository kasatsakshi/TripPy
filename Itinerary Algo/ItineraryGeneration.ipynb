# %%
import requests

# Set up the parameters for the API request
origin = "40.748817,-73.985428"  # latitude and longitude of the starting location
destination = "40.707516,-74.011567"  # latitude and longitude of the destination
mode = "driving"  # the mode of transportation
api_key = "AIzaSyCfCUdTXbP9uUwM0Pu07Okk79JlDX5Dv_g"

# Make the API request
url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
response = requests.get(url)
result = response.json()["routes"][0]

# Extract the time of the route
distance = result["legs"][0]["distance"]["text"]
duration = result["legs"][0]["duration"]["text"]
steps = result["legs"][0]["steps"]

# Check if the duration of the route is 10 hours or less
if "hour" in duration:
    hours, minutes = map(int, duration.split(" "))
    total_minutes = hours * 60 + minutes
else:
    total_minutes = int(duration.split(" ")[0])

if total_minutes > 10 * 60:
    print("The route takes more than 10 hours. Please select a shorter route.")
else:
    # Print the time of the route and the step-by-step directions
    print(f"Total distance: {distance}, total time: {duration}\n")
    for i, step in enumerate(steps):
        print(f"Step {i+1}: {step['html_instructions']}")
        print(f"Distance: {step['distance']['text']}, time: {step['duration']['text']}\n")
# Out:
# Total distance: 5.2 mi, total time: 19 mins
#
# Step 1: Head <b>southeast</b> on <b>W 34th St.</b> toward <b>5th Ave</b>
# Distance: 0.8 mi, time: 7 mins
#
# Step 2: Turn <b>right</b> onto <b>FDR Dr</b>
# Distance: 56 ft, time: 1 min
#
# Step 3: Slight <b>left</b> onto the <b>FDR Drive</b> ramp to <b>Batery Pk S</b>
# Distance: 0.2 mi, time: 1 min
#
# Step 4: Merge onto <b>FDR Dr</b>
# Distance: 3.2 mi, time: 5 mins
#
# Step 5: Take exit <b>2</b> toward <b>Manhattan Civic Ctr</b>
# Distance: 0.2 mi, time: 1 min
#
# Step 6: Merge onto <b>Robert F. Wagner Sr. Place</b>
# Distance: 184 ft, time: 1 min
#
# Step 7: Turn <b>left</b> onto <b>Pearl St</b>
# Distance: 0.2 mi, time: 2 mins
#
# Step 8: Continue onto <b>Water St</b>
# Distance: 0.2 mi, time: 1 min
#
# Step 9: Turn <b>right</b> onto <b>Pine St</b>
# Distance: 0.3 mi, time: 3 mins
#
# Step 10: Turn <b>left</b> onto <b>Broadway</b>
# Distance: 292 ft, time: 1 min

# %%
import requests

# Set up the parameters for the API request
lat = 40.748817
lng = -73.985428
radius = 1000 # in meters
categories = ["restaurant", "bar", "cafe"]
max_price_level = 2
api_key = "AIzaSyCfCUdTXbP9uUwM0Pu07Okk79JlDX5Dv_g"

# Loop through the categories and make a request for each category
for category in categories:
    # Make the API request
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&type={category}&maxprice={max_price_level}&key={api_key}"
    response = requests.get(url)
    results = response.json()["results"]
    
    # Print the results for the current category
    print(f"\n--- {category.upper()} ---")
    for result in results:
        name = result["name"]
        vicinity = result["vicinity"]
        rating = result.get("rating", "N/A")
        price_level = result.get("price_level", "N/A")
        print(f"{name} ({vicinity}) - rating: {rating}, price level: {price_level}")
# Out:
# --- RESTAURANT ---
# Oohu Szechuan & Canton Cuisines 兀湖川菜馆 中餐 点心 纽约必吃 (128 West 36th Street, New York) - rating: 4.2, price level: 2
# Stout NYC (133 West 33rd Street, New York) - rating: 4.2, price level: 2
# Café China (59 West 37th Street, New York) - rating: 4.3, price level: 2
# Bryant Park Grill (25 West 40th Street, New York) - rating: 4.3, price level: 2
# The Kunjip | Korean BBQ NYC (32 West 32nd Street, New York) - rating: 3.7, price level: 2
# Franchia Vegan Café (12 Park Avenue, New York) - rating: 4.5, price level: 2
# The Cutting Room (44 East 32nd Street, New York) - rating: 4.4, price level: 2
# Szechuan Gourmet (21 West 39th Street, New York) - rating: 4.1, price level: 2
# Woorijip (12 West 32nd Street, New York) - rating: 4.4, price level: 1
# The Liberty NYC (29 West 35th Street, New York) - rating: 4.2, price level: 2
# Mr. Broadway (1372 Broadway, New York) - rating: 4.2, price level: 2
# ...

# %%
import requests

# Set up the parameters for the API requests
origin = "New York"  # the starting location
mode = "driving"  # the mode of transportation
max_travel_time = 2 * 60 * 60  # the maximum travel time in seconds
api_key = "AIzaSyCfCUdTXbP9uUwM0Pu07Okk79JlDX5Dv_g"

# Define the categories of places to visit
categories = ["restaurant"]

# Create an empty list to store the places
places = []

# Loop through the categories and find nearby places using the Google Places API
for category in categories:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={origin}&type={category}&key={api_key}"
    response = requests.get(url)
    results = response.json()["results"]
    # Add the places to the list
    for result in results:
        name = result["name"]
        location = f"{result['geometry']['location']['lat']},{result['geometry']['location']['lng']}"
        places.append((name, location, category))

# Create an empty list to store the itinerary
itinerary = []
print(places)
# Loop through the places and calculate the travel time between them using the Google Directions API
for i in range(len(places)):
    for j in range(i+1, len(places)):
        origin = places[i][1]
        destination = places[j][1]
        category = places[i][2]
        
        # Make the API request
        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
        response = requests.get(url)
        result = response.json()["routes"][0]
        
        # Extract the duration of the route
        duration = result["legs"][0]["duration"]["value"]
        
        # Check if the duration is within the maximum travel time
        if duration <= max_travel_time:
            # Add the places and duration to the itinerary
            itinerary.append((places[i][0], places[j][0], category, duration))

# Sort the itinerary by duration in ascending order
itinerary.sort(key=lambda x: x[3])

# Print the itinerary
for i, place in enumerate(itinerary):
    print(f"Day {i+1}: {place[0]} -> {place[1]} ({place[2]}), travel time: {place[3]//60} minutes")
# Out:
# []
# []

# %%
# 0: Free
# 1: Inexpensive
# 2: Moderate
# 3: Expensive
# 4: Very expensive





# accounting
# airport
# amusement_park
# aquarium
# art_gallery
# atm
# bakery
# bank
# bar
# beauty_salon
# bicycle_store
# book_store
# bowling_alley
# bus_station
# cafe
# campground
# car_dealer
# car_rental
# car_repair
# car_wash
# casino
# cemetery
# church
# city_hall
# clothing_store
# convenience_store
# courthouse
# dentist
# department_store
# doctor
# electrician
# electronics_store
# embassy
# fire_station
# florist
# funeral_home
# furniture_store
# gas_station
# gym
# hair_care
# hardware_store
# hindu_temple
# home_goods_store
# hospital
# insurance_agency
# jewelry_store
# laundry
# lawyer
# library
# liquor_store
# local_government_office
# locksmith
# lodging
# meal_delivery
# meal_takeaway
# mosque
# movie_rental
# movie_theater
# moving_company
# museum
# night_club
# painter
# park
# parking
# pet_store
# pharmacy
# physiotherapist
# plumber
# police
# post_office
# primary_school
# real_estate_agency
# restaurant
# roofing_contractor
# rv_park
# school
# secondary_school
# shoe_store
# shopping_mall
# spa
# stadium
# storage
# store
# subway_station
# supermarket
# synagogue
# taxi_stand
# tourist_attraction
# train_station
# transit_station
# travel_agency
# university
# veterinary_care
# zoo

# %%
import requests

# Set up the parameters for the API requests
origin = "New York"  # the starting location
mode = "driving"  # the mode of transportation
# max_travel_time = 10 * 60 * 60  # the maximum travel time in seconds
api_key = "AIzaSyCfCUdTXbP9uUwM0Pu07Okk79JlDX5Dv_g"  # Replace with your actual API key

# Define the categories of places to visit
categories = ["restaurant", "museum", "park"]

# Create an empty list to store the places
places = []

# Loop through the categories and find nearby places using the Google Places API
for category in categories:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={origin}&type={category}&key={api_key}"
    response = requests.get(url)
    results = response.json()["results"]
    
    # Add the places to the list
    for result in results:
        name = result["name"]
        location = f"{result['geometry']['location']['lat']},{result['geometry']['location']['lng']}"
        places.append((name, location, category))

# Create an empty list to store the itinerary
itinerary = []

# Loop through the places and calculate the travel time between them using the Google Directions API
for i in range(len(places)):
    for j in range(i+1, len(places)):
        origin = places[i][1]
        destination = places[j][1]
        category = places[i][2]
        
        # Make the API request
        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
        response = requests.get(url)
        result = response.json()["routes"][0]
        
        # Extract the duration of the route
        duration = result["legs"][0]["duration"]["value"]
        
        # Check if the duration is within the maximum travel time
        if duration <= max_travel_time:
            # Add the places and duration to the itinerary
            itinerary.append((places[i][0], places[j][0], category, duration))

# Sort the itinerary by duration in ascending order
itinerary.sort(key=lambda x: x[3])

# Print the itinerary
for i, place in enumerate(itinerary):
    print(f"Day {i+1}: {place[0]} -> {place[1]} ({place[2]}), travel time: {place[3]//60} minutes")

# %%
import requests

# Set up the parameters for the API requests
origin = "New York"  # the starting location
mode = "driving"  # the mode of transportation
max_travel_time = 10 * 60 * 60  # the maximum travel time in seconds
api_key = "your-api-key"  # Replace with your actual API key

# Define the categories of places to visit
categories = ["restaurant", "museum", "park"]

# Create an empty list to store the places
places = []

# Loop through the categories and find nearby places using the Google Places API
for category in categories:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={origin}&type={category}&key={api_key}"
    response = requests.get(url)
    try:
        response.raise_for_status()  # raise an error if there is an issue with the request
        results = response.json()["results"]
        
        # Add the places to the list
        for result in results:
            name = result["name"]
            location = f"{result['geometry']['location']['lat']},{result['geometry']['location']['lng']}"
            places.append((name, location, category))
    except requests.exceptions.HTTPError as error:
        print(f"Error: {error}")
        print(f"Response: {response.text}")

# Create an empty list to store the itinerary
itinerary = []

# Loop through the places and calculate the travel time between them using the Google Directions API
for i in range(len(places)):
    for j in range(i+1, len(places)):
        origin = places[i][1]
        destination = places[j][1]
        category = places[i][2]
        
        # Make the API request
        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
        response = requests.get(url)
        try:
            response.raise_for_status()  # raise an error if there is an issue with the request
            result = response.json()["routes"][0]
            
            # Extract the duration of the route
            duration = result["legs"][0]["duration"]["value"]
            
            # Check if the duration is within the maximum travel time
            if duration <= max_travel_time:
                # Add the places and duration to the itinerary
                itinerary.append((places[i][0], places[j][0], category, duration))
        except requests.exceptions.HTTPError as error:
            print(f"Error: {error}")
            print(f"Response: {response.text}")

# Sort the itinerary by duration in ascending order
itinerary.sort(key=lambda x: x[3])

# Print the itinerary
for i, place in enumerate(itinerary):
    print(f"Day {i+1}: {place[0]} -> {place[1]} ({place[2]}), travel time: {place[3]//60} minutes")

# %%
import requests

origin = "New York" 
mode = "driving" 
max_travel_time =  60   # the maximum travel time in seconds
api_key = "AIzaSyCfCUdTXbP9uUwM0Pu07Okk79JlDX5Dv_g" 

# Use the Google Geocoding API to convert the starting location to a latitude and longitude
geocoding_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={origin}&key={api_key}"
geocoding_response = requests.get(geocoding_url)
geocoding_result = geocoding_response.json()["results"][0]
lat = geocoding_result["geometry"]["location"]["lat"]
lng = geocoding_result["geometry"]["location"]["lng"]

categories = ["restaurant", "museum", "park"]

places = []

for category in categories:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius=10000&type={category}&key={api_key}"
    response = requests.get(url)
    try:
        response.raise_for_status()  # raise an error if there is an issue with the request
        results = response.json()["results"]

        for result in results:
            name = result["name"]
            location = f"{result['geometry']['location']['lat']},{result['geometry']['location']['lng']}"
            places.append((name, location, category))
    except requests.exceptions.HTTPError as error:
        print(f"Error: {error}")
        print(f"Response: {response.text}")

itinerary = []

for i in range(len(places)):
    for j in range(i+1, len(places)):
        origin = places[i][1]
        destination = places[j][1]
        category = places[i][2]

        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
        response = requests.get(url)
        try:
            response.raise_for_status()
            result = response.json()["routes"][0]
            
            duration = result["legs"][0]["duration"]["value"]
            
            if duration <= max_travel_time:
                itinerary.append((places[i][0], places[j][0], category, duration))
        except requests.exceptions.HTTPError as error:
            print(f"Error: {error}")
            print(f"Response: {response.text}")

itinerary.sort(key=lambda x: (x[2], x[3]))

for place1, place2, category, duration in itinerary:
    lat1, lng1 = [float(x) for x in places[0][1].split(',')]
    lat2, lng2 = [float(x) for x in places[1][1].split(',')]
    print(f"{place1} ({lat1:.4f}, {lng1:.4f}) to {place2} ({lat2:.4f}, {lng2:.4f}) ({category}): {duration/60:.1f} minutes")
# Out:
# The Skyscraper Museum (40.7156, -74.0090) to Robert F. Wagner Jr. Park (40.7198, -74.0001) (museum): 0.1 minutes
# BODIES...The Exhibition New York (40.7156, -74.0090) to South Street Seaport Museum (40.7198, -74.0001) (museum): 0.1 minutes
# Museum of Jewish Heritage – A Living Memorial to the Holocaust (40.7156, -74.0090) to The Skyscraper Museum (40.7198, -74.0001) (museum): 0.1 minutes
# Museum of Jewish Heritage – A Living Memorial to the Holocaust (40.7156, -74.0090) to Robert F. Wagner Jr. Park (40.7198, -74.0001) (museum): 0.2 minutes
# Museum of Jewish Heritage – A Living Memorial to the Holocaust (40.7156, -74.0090) to Battery Park City Parks (40.7198, -74.0001) (museum): 0.4 minutes
# The Skyscraper Museum (40.7156, -74.0090) to Battery Park City Parks (40.7198, -74.0001) (museum): 0.7 minutes
# Federal Hall (40.7156, -74.0090) to Conservancy-Historic Battery (40.7198, -74.0001) (museum): 1.0 minutes
# ...

# %%
import json
import requests

origin = "New York" 
mode = "driving" 
max_travel_time =  60   # the maximum travel time in seconds
api_key = "AIzaSyCfCUdTXbP9uUwM0Pu07Okk79JlDX5Dv_g" 

# Use the Google Geocoding API to convert the starting location to a latitude and longitude
geocoding_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={origin}&key={api_key}"
geocoding_response = requests.get(geocoding_url)
geocoding_result = geocoding_response.json()["results"][0]
lat = geocoding_result["geometry"]["location"]["lat"]
lng = geocoding_result["geometry"]["location"]["lng"]

categories = ["restaurant", "museum", "park"]

places = []

for category in categories:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius=10000&type={category}&key={api_key}"
    response = requests.get(url)
    try:
        response.raise_for_status()  # raise an error if there is an issue with the request
        results = response.json()["results"]

        for result in results:
            name = result["name"]
            location = f"{result['geometry']['location']['lat']},{result['geometry']['location']['lng']}"
            places.append((name, location, category))
    except requests.exceptions.HTTPError as error:
        print(f"Error: {error}")
        print(f"Response: {response.text}")

itinerary = []

for i in range(len(places)):
    for j in range(i+1, len(places)):
        origin = places[i][1]
        destination = places[j][1]
        category = places[i][2]

        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
        response = requests.get(url)
        try:
            response.raise_for_status()
            result = response.json()["routes"][0]
            
            duration = result["legs"][0]["duration"]["value"]
            
            if duration <= max_travel_time:
                itinerary.append((places[i][0], places[j][0], category, duration))
        except requests.exceptions.HTTPError as error:
            print(f"Error: {error}")
            print(f"Response: {response.text}")

itinerary.sort(key=lambda x: (x[2], x[3]))

output = []

for place1, place2, category, duration in itinerary:
    lat1, lng1 = [float(x) for x in places[0][1].split(',')]
    lat2, lng2 = [float(x) for x in places[1][1].split(',')]
    item = {
        "place": [{"name": place1, "lat": lat1, "lng": lng1},{"name": place2, "lat": lat2, "lng": lng2} ],
        "category": category,
        "duration": duration/60
    }
    output.append(item)

print(json.dumps(output))
# Out:
# [{"place": [{"name": "The Skyscraper Museum", "lat": 40.7156143, "lng": -74.00896709999999}, {"name": "Robert F. Wagner Jr. Park", "lat": 40.71981419999999, "lng": -74.00007339999999}], "category": "museum", "duration": 0.08333333333333333}, {"place": [{"name": "BODIES...The Exhibition New York", "lat": 40.7156143, "lng": -74.00896709999999}, {"name": "South Street Seaport Museum", "lat": 40.71981419999999, "lng": -74.00007339999999}], "category": "museum", "duration": 0.1}, {"place": [{"name": "Museum of Jewish Heritage \u2013 A Living Memorial to the Holocaust", "lat": 40.7156143, "lng": -74.00896709999999}, {"name": "The Skyscraper Museum", "lat": 40.71981419999999, "lng": -74.00007339999999}], "category": "museum", "duration": 0.15}, {"place": [{"name": "Museum of Jewish Heritage \u2013 A Living Memorial to the Holocaust", "lat": 40.7156143, "lng": -74.00896709999999}, {"name": "Robert F. Wagner Jr. Park", "lat": 40.71981419999999, "lng": -74.00007339999999}], "category": "museum
# ...

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
